# %%
import torch
import torch.nn as nn
import torch.optim as optim
from data_utils import *

dataloaders, dataset_sizes = data_loader('imagenet', './data/ILSVRC2015/Data/CLS-LOC', num_workers=0, batch_size=256)

# %%
dataset_sizes
# Out:
# {'pretrain': 1281167, 'train': 1231167, 'test': 50000, 'valid': 50000}

# %%
samples, labels = next(iter(dataloaders['pretrain']))
print(samples[0].shape)
print(labels.shape)
# Out:
# torch.Size([256, 3, 224, 224])
# torch.Size([256])

# %%
tester = nn.Sequential(
    nn.AdaptiveAvgPool2d(7),
    nn.Conv2d(in_channels=3, out_channels=1, kernel_size=7),
    nn.Sigmoid(),
    nn.Flatten()
)

tester = tester.to('cuda:3')

# %%
output = tester(samples[0].to('cuda:3'))
output.shape
# Out:
# torch.Size([256, 1])

# %%
import time

time_stamp = time.time()

count = 0

for samples, labels in dataloaders['pretrain']:
    count += 1
    print('%d th batch processing' % count)
        
    samples = samples[0].to('cuda:3')
    output = tester(samples)

    
elapsed = time.time() - time_stamp

print(elapsed)
print('썩쎄쓰!!')
# Out:
# 1 th batch processing
# 2 th batch processing
# 3 th batch processing
# 4 th batch processing
# 5 th batch processing
# 6 th batch processing
# 7 th batch processing
# 8 th batch processing
# 9 th batch processing
# 10 th batch processing
# 11 th batch processing
# 12 th batch processing
# 13 th batch processing
# 14 th batch processing
# 15 th batch processing
# 16 th batch processing
# 17 th batch processing
# 18 th batch processing
# 19 th batch processing
# 20 th batch processing
# 21 th batch processing
# 22 th batch processing
# 23 th batch processing
# 24 th batch processing
# 25 th batch processing
# 26 th batch processing
# 27 th batch processing
# 28 th batch processing
# 29 th batch processing
# 30 th batch processing
# 31 th batch processing
# 32 th batch processing
# 33 th batch processing
# 34 th batch processing
# 35 th batch processing
# 36 th batch processing
# 37 th batch processing
# 38 th batch processing
# 39 th batch processing
# 40 th batch processing
# 41 th batch processing
# 42 th batch processing
# 43 th batch processing
# 44 th batch processing
# 45 th batch processing
# 46 th batch processing
# 47 th batch processing
# 48 th batch processing
# 49 th batch processing
# 50 th batch processing
# 51 th batch processing
# 52 th batch processing
# 53 th batch processing
# 54 th batch processing
# 55 th batch processing
# 56 th batch processing
# 57 th batch processing
# 58 th batch processing
# 59 th batch processing
# 60 th batch processing
# 61 th batch processing
# 62 th batch processing
# 63 th batch processing
# 64 th batch processing
# 65 th batch processing
# 66 th batch processing
# 67 th batch processing
# 68 th batch processing
# 69 th batch processing
# 70 th batch processing
# 71 th batch processing
# 72 th batch processing
# 73 th batch processing
# 74 th batch processing
# 75 th batch processing
# 76 th batch processing
# 77 th batch processing
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:802: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 78 th batch processing
# 79 th batch processing
# 80 th batch processing
# 81 th batch processing
# 82 th batch processing
# 83 th batch processing
# 84 th batch processing
# 85 th batch processing
# 86 th batch processing
# 87 th batch processing
# 88 th batch processing
# 89 th batch processing
# 90 th batch processing
# 91 th batch processing
# 92 th batch processing
# 93 th batch processing
# 94 th batch processing
# 95 th batch processing
# 96 th batch processing
# 97 th batch processing
# 98 th batch processing
# 99 th batch processing
# 100 th batch processing
# 101 th batch processing
# 102 th batch processing
# 103 th batch processing
# 104 th batch processing
# 105 th batch processing
# 106 th batch processing
# 107 th batch processing
# 108 th batch processing
# 109 th batch processing
# 110 th batch processing
# 111 th batch processing
# 112 th batch processing
# 113 th batch processing
# 114 th batch processing
# 115 th batch processing
# 116 th batch processing
# 117 th batch processing
# 118 th batch processing
# 119 th batch processing
# 120 th batch processing
# 121 th batch processing
# 122 th batch processing
# 123 th batch processing
# 124 th batch processing
# 125 th batch processing
# 126 th batch processing
# 127 th batch processing
# 128 th batch processing
# 129 th batch processing
# 130 th batch processing
# 131 th batch processing
# 132 th batch processing
# 133 th batch processing
# 134 th batch processing
# 135 th batch processing
# 136 th batch processing
# 137 th batch processing
# 138 th batch processing
# 139 th batch processing
# 140 th batch processing
# 141 th batch processing
# 142 th batch processing
# 143 th batch processing
# 144 th batch processing
# 145 th batch processing
# 146 th batch processing
# 147 th batch processing
# 148 th batch processing
# 149 th batch processing
# 150 th batch processing
# 151 th batch processing
# 152 th batch processing
# 153 th batch processing
# 154 th batch processing
# 155 th batch processing
# 156 th batch processing
# 157 th batch processing
# 158 th batch processing
# 159 th batch processing
# 160 th batch processing
# 161 th batch processing
# 162 th batch processing
# 163 th batch processing
# 164 th batch processing
# 165 th batch processing
# 166 th batch processing
# 167 th batch processing
# 168 th batch processing
# 169 th batch processing
# 170 th batch processing
# 171 th batch processing
# 172 th batch processing
# 173 th batch processing
# 174 th batch processing
# 175 th batch processing
# 176 th batch processing
# 177 th batch processing
# 178 th batch processing
# 179 th batch processing
# 180 th batch processing
# 181 th batch processing
# 182 th batch processing
# 183 th batch processing
# 184 th batch processing
# 185 th batch processing
# 186 th batch processing
# 187 th batch processing
# 188 th batch processing
# 189 th batch processing
# 190 th batch processing
# 191 th batch processing
# 192 th batch processing
# 193 th batch processing
# 194 th batch processing
# 195 th batch processing
# 196 th batch processing
# 197 th batch processing
# 198 th batch processing
# 199 th batch processing
# 200 th batch processing
# 201 th batch processing
# 202 th batch processing
# 203 th batch processing
# 204 th batch processing
# 205 th batch processing
# 206 th batch processing
# 207 th batch processing
# 208 th batch processing
# 209 th batch processing
# 210 th batch processing
# 211 th batch processing
# 212 th batch processing
# 213 th batch processing
# 214 th batch processing
# 215 th batch processing
# 216 th batch processing
# 217 th batch processing
# 218 th batch processing
# 219 th batch processing
# 220 th batch processing
# 221 th batch processing
# 222 th batch processing
# 223 th batch processing
# 224 th batch processing
# 225 th batch processing
# 226 th batch processing
# 227 th batch processing
# 228 th batch processing
# 229 th batch processing
# 230 th batch processing
# 231 th batch processing
# 232 th batch processing
# 233 th batch processing
# 234 th batch processing
# 235 th batch processing
# 236 th batch processing
# 237 th batch processing
# 238 th batch processing
# 239 th batch processing
# 240 th batch processing
# 241 th batch processing
# 242 th batch processing
# 243 th batch processing
# 244 th batch processing
# 245 th batch processing
# 246 th batch processing
# 247 th batch processing
# 248 th batch processing
# 249 th batch processing
# 250 th batch processing
# 251 th batch processing
# 252 th batch processing
# 253 th batch processing
# 254 th batch processing
# 255 th batch processing
# 256 th batch processing
# 257 th batch processing
# 258 th batch processing
# 259 th batch processing
# 260 th batch processing
# 261 th batch processing
# 262 th batch processing
# 263 th batch processing
# 264 th batch processing
# 265 th batch processing
# 266 th batch processing
# 267 th batch processing
# 268 th batch processing
# 269 th batch processing
# 270 th batch processing
# 271 th batch processing
# 272 th batch processing
# 273 th batch processing
# 274 th batch processing
# 275 th batch processing
# 276 th batch processing
# 277 th batch processing
# 278 th batch processing
# 279 th batch processing
# 280 th batch processing
# 281 th batch processing
# 282 th batch processing
# 283 th batch processing
# 284 th batch processing
# 285 th batch processing
# 286 th batch processing
# 287 th batch processing
# 288 th batch processing
# 289 th batch processing
# 290 th batch processing
# 291 th batch processing
# 292 th batch processing
# 293 th batch processing
# 294 th batch processing
# 295 th batch processing
# 296 th batch processing
# 297 th batch processing
# 298 th batch processing
# 299 th batch processing
# 300 th batch processing
# 301 th batch processing
# 302 th batch processing
# 303 th batch processing
# 304 th batch processing
# 305 th batch processing
# 306 th batch processing
# 307 th batch processing
# 308 th batch processing
# 309 th batch processing
# 310 th batch processing
# 311 th batch processing
# 312 th batch processing
# 313 th batch processing
# 314 th batch processing
# 315 th batch processing
# 316 th batch processing
# 317 th batch processing
# 318 th batch processing
# 319 th batch processing
# 320 th batch processing
# 321 th batch processing
# 322 th batch processing
# 323 th batch processing
# 324 th batch processing
# 325 th batch processing
# 326 th batch processing
# 327 th batch processing
# 328 th batch processing
# 329 th batch processing
# 330 th batch processing
# 331 th batch processing
# 332 th batch processing
# 333 th batch processing
# 334 th batch processing
# 335 th batch processing
# 336 th batch processing
# 337 th batch processing
# 338 th batch processing
# 339 th batch processing
# 340 th batch processing
# 341 th batch processing
# 342 th batch processing
# 343 th batch processing
# 344 th batch processing
# 345 th batch processing
# 346 th batch processing
# 347 th batch processing
# 348 th batch processing
# 349 th batch processing
# 350 th batch processing
# 351 th batch processing
# 352 th batch processing
# 353 th batch processing
# 354 th batch processing
# 355 th batch processing
# 356 th batch processing
# 357 th batch processing
# 358 th batch processing
# 359 th batch processing
# 360 th batch processing
# 361 th batch processing
# 362 th batch processing
# 363 th batch processing
# 364 th batch processing
# 365 th batch processing
# 366 th batch processing
# 367 th batch processing
# 368 th batch processing
# 369 th batch processing
# 370 th batch processing
# 371 th batch processing
# 372 th batch processing
# 373 th batch processing
# 374 th batch processing
# 375 th batch processing
# 376 th batch processing
# 377 th batch processing
# 378 th batch processing
# 379 th batch processing
# 380 th batch processing
# 381 th batch processing
# 382 th batch processing
# 383 th batch processing
# 384 th batch processing
# 385 th batch processing
# 386 th batch processing
# 387 th batch processing
# 388 th batch processing
# 389 th batch processing
# 390 th batch processing
# 391 th batch processing
# 392 th batch processing
# 393 th batch processing
# 394 th batch processing
# 395 th batch processing
# 396 th batch processing
# 397 th batch processing
# 398 th batch processing
# 399 th batch processing
# 400 th batch processing
# 401 th batch processing
# 402 th batch processing
# 403 th batch processing
# 404 th batch processing
# 405 th batch processing
# 406 th batch processing
# 407 th batch processing
# 408 th batch processing
# 409 th batch processing
# 410 th batch processing
# 411 th batch processing
# 412 th batch processing
# 413 th batch processing
# 414 th batch processing
# 415 th batch processing
# 416 th batch processing
# 417 th batch processing
# 418 th batch processing
# 419 th batch processing
# 420 th batch processing
# 421 th batch processing
# 422 th batch processing
# 423 th batch processing
# 424 th batch processing
# 425 th batch processing
# 426 th batch processing
# 427 th batch processing
# 428 th batch processing
# 429 th batch processing
# 430 th batch processing
# 431 th batch processing
# 432 th batch processing
# 433 th batch processing
# 434 th batch processing
# 435 th batch processing
# 436 th batch processing
# 437 th batch processing
# 438 th batch processing
# 439 th batch processing
# 440 th batch processing
# 441 th batch processing
# 442 th batch processing
# 443 th batch processing
# 444 th batch processing
# 445 th batch processing
# 446 th batch processing
# 447 th batch processing
# 448 th batch processing
# 449 th batch processing
# 450 th batch processing
# 451 th batch processing
# 452 th batch processing
# 453 th batch processing
# 454 th batch processing
# 455 th batch processing
# 456 th batch processing
# 457 th batch processing
# 458 th batch processing
# 459 th batch processing
# 460 th batch processing
# 461 th batch processing
# 462 th batch processing
# 463 th batch processing
# 464 th batch processing
# 465 th batch processing
# 466 th batch processing
# 467 th batch processing
# 468 th batch processing
# 469 th batch processing
# 470 th batch processing
# 471 th batch processing
# 472 th batch processing
# 473 th batch processing
# 474 th batch processing
# 475 th batch processing
# 476 th batch processing
# 477 th batch processing
# 478 th batch processing
# 479 th batch processing
# 480 th batch processing
# 481 th batch processing
# 482 th batch processing
# 483 th batch processing
# 484 th batch processing
# 485 th batch processing
# 486 th batch processing
# 487 th batch processing
# 488 th batch processing
# 489 th batch processing
# 490 th batch processing
# 491 th batch processing
# 492 th batch processing
# 493 th batch processing
# 494 th batch processing
# 495 th batch processing
# 496 th batch processing
# 497 th batch processing
# 498 th batch processing
# 499 th batch processing
# 500 th batch processing
# 501 th batch processing
# 502 th batch processing
# 503 th batch processing
# 504 th batch processing
# 505 th batch processing
# 506 th batch processing
# 507 th batch processing
# 508 th batch processing
# 509 th batch processing
# 510 th batch processing
# 511 th batch processing
# 512 th batch processing
# 513 th batch processing
# 514 th batch processing
# 515 th batch processing
# 516 th batch processing
# 517 th batch processing
# 518 th batch processing
# 519 th batch processing
# 520 th batch processing
# 521 th batch processing
# 522 th batch processing
# 523 th batch processing
# 524 th batch processing
# 525 th batch processing
# 526 th batch processing
# 527 th batch processing
# 528 th batch processing
# 529 th batch processing
# 530 th batch processing
# 531 th batch processing
# 532 th batch processing
# 533 th batch processing
# 534 th batch processing
# 535 th batch processing
# 536 th batch processing
# 537 th batch processing
# 538 th batch processing
# 539 th batch processing
# 540 th batch processing
# 541 th batch processing
# 542 th batch processing
# 543 th batch processing
# 544 th batch processing
# 545 th batch processing
# 546 th batch processing
# 547 th batch processing
# 548 th batch processing
# 549 th batch processing
# 550 th batch processing
# 551 th batch processing
# 552 th batch processing
# 553 th batch processing
# 554 th batch processing
# 555 th batch processing
# 556 th batch processing
# 557 th batch processing
# 558 th batch processing
# 559 th batch processing
# 560 th batch processing
# 561 th batch processing
# 562 th batch processing
# 563 th batch processing
# 564 th batch processing
# 565 th batch processing
# 566 th batch processing
# 567 th batch processing
# 568 th batch processing
# 569 th batch processing
# 570 th batch processing
# 571 th batch processing
# 572 th batch processing
# 573 th batch processing
# 574 th batch processing
# 575 th batch processing
# 576 th batch processing
# 577 th batch processing
# 578 th batch processing
# 579 th batch processing
# 580 th batch processing
# 581 th batch processing
# 582 th batch processing
# 583 th batch processing
# 584 th batch processing
# 585 th batch processing
# 586 th batch processing
# 587 th batch processing
# 588 th batch processing
# 589 th batch processing
# 590 th batch processing
# 591 th batch processing
# 592 th batch processing
# 593 th batch processing
# 594 th batch processing
# 595 th batch processing
# 596 th batch processing
# 597 th batch processing
# 598 th batch processing
# 599 th batch processing
# 600 th batch processing
# 601 th batch processing
# 602 th batch processing
# 603 th batch processing
# 604 th batch processing
# 605 th batch processing
# 606 th batch processing
# 607 th batch processing
# 608 th batch processing
# 609 th batch processing
# 610 th batch processing
# 611 th batch processing
# 612 th batch processing
# 613 th batch processing
# 614 th batch processing
# 615 th batch processing
# 616 th batch processing
# 617 th batch processing
# 618 th batch processing
# 619 th batch processing
# 620 th batch processing
# 621 th batch processing
# 622 th batch processing
# 623 th batch processing
# 624 th batch processing
# 625 th batch processing
# 626 th batch processing
# 627 th batch processing
# 628 th batch processing
# 629 th batch processing
# 630 th batch processing
# 631 th batch processing
# 632 th batch processing
# 633 th batch processing
# 634 th batch processing
# 635 th batch processing
# 636 th batch processing
# 637 th batch processing
# 638 th batch processing
# 639 th batch processing
# 640 th batch processing
# 641 th batch processing
# 642 th batch processing
# 643 th batch processing
# 644 th batch processing
# 645 th batch processing
# 646 th batch processing
# 647 th batch processing
# 648 th batch processing
# 649 th batch processing
# 650 th batch processing
# 651 th batch processing
# 652 th batch processing
# 653 th batch processing
# 654 th batch processing
# 655 th batch processing
# 656 th batch processing
# 657 th batch processing
# 658 th batch processing
# 659 th batch processing
# 660 th batch processing
# 661 th batch processing
# 662 th batch processing
# 663 th batch processing
# 664 th batch processing
# 665 th batch processing
# 666 th batch processing
# 667 th batch processing
# 668 th batch processing
# 669 th batch processing
# 670 th batch processing
# 671 th batch processing
# 672 th batch processing
# 673 th batch processing
# 674 th batch processing
# 675 th batch processing
# 676 th batch processing
# 677 th batch processing
# 678 th batch processing
# 679 th batch processing
# 680 th batch processing
# 681 th batch processing
# 682 th batch processing
# 683 th batch processing
# 684 th batch processing
# 685 th batch processing
# 686 th batch processing
# 687 th batch processing
# 688 th batch processing
# 689 th batch processing
# 690 th batch processing
# 691 th batch processing
# 692 th batch processing
# 693 th batch processing
# 694 th batch processing
# 695 th batch processing
# 696 th batch processing
# 697 th batch processing
# 698 th batch processing
# 699 th batch processing
# 700 th batch processing
# 701 th batch processing
# 702 th batch processing
# 703 th batch processing
# 704 th batch processing
# 705 th batch processing
# 706 th batch processing
# 707 th batch processing
# 708 th batch processing
# 709 th batch processing
# 710 th batch processing
# 711 th batch processing
# 712 th batch processing
# 713 th batch processing
# 714 th batch processing
# 715 th batch processing
# 716 th batch processing
# 717 th batch processing
# 718 th batch processing
# 719 th batch processing
# 720 th batch processing
# 721 th batch processing
# 722 th batch processing
# 723 th batch processing
# 724 th batch processing
# 725 th batch processing
# 726 th batch processing
# 727 th batch processing
# 728 th batch processing
# 729 th batch processing
# 730 th batch processing
# 731 th batch processing
# 732 th batch processing
# 733 th batch processing
# 734 th batch processing
# 735 th batch processing
# 736 th batch processing
# 737 th batch processing
# 738 th batch processing
# 739 th batch processing
# 740 th batch processing
# 741 th batch processing
# 742 th batch processing
# 743 th batch processing
# 744 th batch processing
# 745 th batch processing
# 746 th batch processing
# 747 th batch processing
# 748 th batch processing
# 749 th batch processing
# 750 th batch processing
# 751 th batch processing
# 752 th batch processing
# 753 th batch processing
# 754 th batch processing
# 755 th batch processing
# 756 th batch processing
# 757 th batch processing
# 758 th batch processing
# 759 th batch processing
# 760 th batch processing
# 761 th batch processing
# 762 th batch processing
# 763 th batch processing
# 764 th batch processing
# 765 th batch processing
# 766 th batch processing
# 767 th batch processing
# 768 th batch processing
# 769 th batch processing
# 770 th batch processing
# 771 th batch processing
# 772 th batch processing
# 773 th batch processing
# 774 th batch processing
# 775 th batch processing
# 776 th batch processing
# 777 th batch processing
# 778 th batch processing
# 779 th batch processing
# 780 th batch processing
# 781 th batch processing
# 782 th batch processing
# 783 th batch processing
# 784 th batch processing
# 785 th batch processing
# 786 th batch processing
# 787 th batch processing
# 788 th batch processing
# 789 th batch processing
# 790 th batch processing
# 791 th batch processing
# 792 th batch processing
# 793 th batch processing
# 794 th batch processing
# 795 th batch processing
# 796 th batch processing
# 797 th batch processing
# 798 th batch processing
# 799 th batch processing
# 800 th batch processing
# 801 th batch processing
# 802 th batch processing
# 803 th batch processing
# 804 th batch processing
# 805 th batch processing
# 806 th batch processing
# 807 th batch processing
# 808 th batch processing
# 809 th batch processing
# 810 th batch processing
# 811 th batch processing
# 812 th batch processing
# 813 th batch processing
# 814 th batch processing
# 815 th batch processing
# 816 th batch processing
# 817 th batch processing
# 818 th batch processing
# 819 th batch processing
# 820 th batch processing
# 821 th batch processing
# 822 th batch processing
# 823 th batch processing
# 824 th batch processing
# 825 th batch processing
# 826 th batch processing
# 827 th batch processing
# 828 th batch processing
# 829 th batch processing
# 830 th batch processing
# 831 th batch processing
# 832 th batch processing
# 833 th batch processing
# 834 th batch processing
# 835 th batch processing
# 836 th batch processing
# 837 th batch processing
# 838 th batch processing
# 839 th batch processing
# 840 th batch processing
# 841 th batch processing
# 842 th batch processing
# 843 th batch processing
# 844 th batch processing
# 845 th batch processing
# 846 th batch processing
# 847 th batch processing
# 848 th batch processing
# 849 th batch processing
# 850 th batch processing
# 851 th batch processing
# 852 th batch processing
# 853 th batch processing
# 854 th batch processing
# 855 th batch processing
# 856 th batch processing
# 857 th batch processing
# 858 th batch processing
# 859 th batch processing
# 860 th batch processing
# 861 th batch processing
# 862 th batch processing
# 863 th batch processing
# 864 th batch processing
# 865 th batch processing
# 866 th batch processing
# 867 th batch processing
# 868 th batch processing
# 869 th batch processing
# 870 th batch processing
# 871 th batch processing
# 872 th batch processing
# 873 th batch processing
# 874 th batch processing
# 875 th batch processing
# 876 th batch processing
# 877 th batch processing
# 878 th batch processing
# 879 th batch processing
# 880 th batch processing
# 881 th batch processing
# 882 th batch processing
# 883 th batch processing
# 884 th batch processing
# 885 th batch processing
# 886 th batch processing
# 887 th batch processing
# 888 th batch processing
# 889 th batch processing
# 890 th batch processing
# 891 th batch processing
# 892 th batch processing
# 893 th batch processing
# 894 th batch processing
# 895 th batch processing
# 896 th batch processing
# 897 th batch processing
# 898 th batch processing
# 899 th batch processing
# 900 th batch processing
# 901 th batch processing
# 902 th batch processing
# 903 th batch processing
# 904 th batch processing
# 905 th batch processing
# 906 th batch processing
# 907 th batch processing
# 908 th batch processing
# 909 th batch processing
# 910 th batch processing
# 911 th batch processing
# 912 th batch processing
# 913 th batch processing
# 914 th batch processing
# 915 th batch processing
# 916 th batch processing
# 917 th batch processing
# 918 th batch processing
# 919 th batch processing
# 920 th batch processing
# 921 th batch processing
# 922 th batch processing
# 923 th batch processing
# 924 th batch processing
# 925 th batch processing
# 926 th batch processing
# 927 th batch processing
# 928 th batch processing
# 929 th batch processing
# 930 th batch processing
# 931 th batch processing
# 932 th batch processing
# 933 th batch processing
# 934 th batch processing
# 935 th batch processing
# 936 th batch processing
# 937 th batch processing
# 938 th batch processing
# 939 th batch processing
# 940 th batch processing
# 941 th batch processing
# 942 th batch processing
# 943 th batch processing
# 944 th batch processing
# 945 th batch processing
# 946 th batch processing
# 947 th batch processing
# 948 th batch processing
# 949 th batch processing
# 950 th batch processing
# 951 th batch processing
# 952 th batch processing
# 953 th batch processing
# 954 th batch processing
# 955 th batch processing
# 956 th batch processing
# 957 th batch processing
# 958 th batch processing
# 959 th batch processing
# 960 th batch processing
# 961 th batch processing
# 962 th batch processing
# 963 th batch processing
# 964 th batch processing
# 965 th batch processing
# 966 th batch processing
# 967 th batch processing
# 968 th batch processing
# 969 th batch processing
# 970 th batch processing
# 971 th batch processing
# 972 th batch processing
# 973 th batch processing
# 974 th batch processing
# 975 th batch processing
# 976 th batch processing
# 977 th batch processing
# 978 th batch processing
# 979 th batch processing
# 980 th batch processing
# 981 th batch processing
# 982 th batch processing
# 983 th batch processing
# 984 th batch processing
# 985 th batch processing
# 986 th batch processing
# 987 th batch processing
# 988 th batch processing
# 989 th batch processing
# 990 th batch processing
# 991 th batch processing
# 992 th batch processing
# 993 th batch processing
# 994 th batch processing
# 995 th batch processing
# 996 th batch processing
# 997 th batch processing
# 998 th batch processing
# 999 th batch processing
# 1000 th batch processing
# 1001 th batch processing
# 1002 th batch processing
# 1003 th batch processing
# 1004 th batch processing
# 1005 th batch processing
# 1006 th batch processing
# 1007 th batch processing
# 1008 th batch processing
# 1009 th batch processing
# 1010 th batch processing
# 1011 th batch processing
# 1012 th batch processing
# 1013 th batch processing
# 1014 th batch processing
# 1015 th batch processing
# 1016 th batch processing
# 1017 th batch processing
# 1018 th batch processing
# 1019 th batch processing
# 1020 th batch processing
# 1021 th batch processing
# 1022 th batch processing
# 1023 th batch processing
# 1024 th batch processing
# 1025 th batch processing
# 1026 th batch processing
# 1027 th batch processing
# 1028 th batch processing
# 1029 th batch processing
# 1030 th batch processing
# 1031 th batch processing
# 1032 th batch processing
# 1033 th batch processing
# 1034 th batch processing
# 1035 th batch processing
# 1036 th batch processing
# 1037 th batch processing
# 1038 th batch processing
# 1039 th batch processing
# 1040 th batch processing
# 1041 th batch processing
# 1042 th batch processing
# 1043 th batch processing
# 1044 th batch processing
# 1045 th batch processing
# 1046 th batch processing
# 1047 th batch processing
# 1048 th batch processing
# 1049 th batch processing
# 1050 th batch processing
# 1051 th batch processing
# 1052 th batch processing
# 1053 th batch processing
# 1054 th batch processing
# 1055 th batch processing
# 1056 th batch processing
# 1057 th batch processing
# 1058 th batch processing
# 1059 th batch processing
# 1060 th batch processing
# 1061 th batch processing
# 1062 th batch processing
# 1063 th batch processing
# 1064 th batch processing
# 1065 th batch processing
# 1066 th batch processing
# 1067 th batch processing
# 1068 th batch processing
# 1069 th batch processing
# 1070 th batch processing
# 1071 th batch processing
# 1072 th batch processing
# 1073 th batch processing
# 1074 th batch processing
# 1075 th batch processing
# 1076 th batch processing
# 1077 th batch processing
# 1078 th batch processing
# 1079 th batch processing
# 1080 th batch processing
# 1081 th batch processing
# 1082 th batch processing
# 1083 th batch processing
# 1084 th batch processing
# 1085 th batch processing
# 1086 th batch processing
# 1087 th batch processing
# 1088 th batch processing
# 1089 th batch processing
# 1090 th batch processing
# 1091 th batch processing
# 1092 th batch processing
# 1093 th batch processing
# 1094 th batch processing
# 1095 th batch processing
# 1096 th batch processing
# 1097 th batch processing
# 1098 th batch processing
# 1099 th batch processing
# 1100 th batch processing
# 1101 th batch processing
# 1102 th batch processing
# 1103 th batch processing
# 1104 th batch processing
# 1105 th batch processing
# 1106 th batch processing
# 1107 th batch processing
# 1108 th batch processing
# 1109 th batch processing
# 1110 th batch processing
# 1111 th batch processing
# 1112 th batch processing
# 1113 th batch processing
# 1114 th batch processing
# 1115 th batch processing
# 1116 th batch processing
# 1117 th batch processing
# 1118 th batch processing
# 1119 th batch processing
# 1120 th batch processing
# 1121 th batch processing
# 1122 th batch processing
# 1123 th batch processing
# 1124 th batch processing
# 1125 th batch processing
# 1126 th batch processing
# 1127 th batch processing
# 1128 th batch processing
# 1129 th batch processing
# 1130 th batch processing
# 1131 th batch processing
# 1132 th batch processing
# 1133 th batch processing
# 1134 th batch processing
# 1135 th batch processing
# 1136 th batch processing
# 1137 th batch processing
# 1138 th batch processing
# 1139 th batch processing
# 1140 th batch processing
# 1141 th batch processing
# 1142 th batch processing
# 1143 th batch processing
# 1144 th batch processing
# 1145 th batch processing
# 1146 th batch processing
# 1147 th batch processing
# 1148 th batch processing
# 1149 th batch processing
# 1150 th batch processing
# 1151 th batch processing
# 1152 th batch processing
# 1153 th batch processing
# 1154 th batch processing
# 1155 th batch processing
# 1156 th batch processing
# 1157 th batch processing
# 1158 th batch processing
# 1159 th batch processing
# 1160 th batch processing
# 1161 th batch processing
# 1162 th batch processing
# 1163 th batch processing
# 1164 th batch processing
# 1165 th batch processing
# 1166 th batch processing
# 1167 th batch processing
# 1168 th batch processing
# 1169 th batch processing
# 1170 th batch processing
# 1171 th batch processing
# 1172 th batch processing
# 1173 th batch processing
# 1174 th batch processing
# 1175 th batch processing
# 1176 th batch processing
# 1177 th batch processing
# 1178 th batch processing
# 1179 th batch processing
# 1180 th batch processing
# 1181 th batch processing
# 1182 th batch processing
# 1183 th batch processing
# 1184 th batch processing
# 1185 th batch processing
# 1186 th batch processing
# 1187 th batch processing
# 1188 th batch processing
# 1189 th batch processing
# 1190 th batch processing
# 1191 th batch processing
# 1192 th batch processing
# 1193 th batch processing
# 1194 th batch processing
# 1195 th batch processing
# 1196 th batch processing
# 1197 th batch processing
# 1198 th batch processing
# 1199 th batch processing
# 1200 th batch processing
# 1201 th batch processing
# 1202 th batch processing
# 1203 th batch processing
# 1204 th batch processing
# 1205 th batch processing
# 1206 th batch processing
# 1207 th batch processing
# 1208 th batch processing
# 1209 th batch processing
# 1210 th batch processing
# 1211 th batch processing
# 1212 th batch processing
# 1213 th batch processing
# 1214 th batch processing
# 1215 th batch processing
# 1216 th batch processing
# 1217 th batch processing
# 1218 th batch processing
# 1219 th batch processing
# 1220 th batch processing
# 1221 th batch processing
# 1222 th batch processing
# 1223 th batch processing
# 1224 th batch processing
# 1225 th batch processing
# 1226 th batch processing
# 1227 th batch processing
# 1228 th batch processing
# 1229 th batch processing
# 1230 th batch processing
# 1231 th batch processing
# 1232 th batch processing
# 1233 th batch processing
# 1234 th batch processing
# 1235 th batch processing
# 1236 th batch processing
# 1237 th batch processing
# 1238 th batch processing
# 1239 th batch processing
# 1240 th batch processing
# 1241 th batch processing
# 1242 th batch processing
# 1243 th batch processing
# 1244 th batch processing
# 1245 th batch processing
# 1246 th batch processing
# 1247 th batch processing
# 1248 th batch processing
# 1249 th batch processing
# 1250 th batch processing
# 1251 th batch processing
# 1252 th batch processing
# 1253 th batch processing
# 1254 th batch processing
# 1255 th batch processing
# 1256 th batch processing
# 1257 th batch processing
# 1258 th batch processing
# 1259 th batch processing
# 1260 th batch processing
# 1261 th batch processing
# 1262 th batch processing
# 1263 th batch processing
# 1264 th batch processing
# 1265 th batch processing
# 1266 th batch processing
# 1267 th batch processing
# 1268 th batch processing
# 1269 th batch processing
# 1270 th batch processing
# 1271 th batch processing
# 1272 th batch processing
# 1273 th batch processing
# 1274 th batch processing
# 1275 th batch processing
# 1276 th batch processing
# 1277 th batch processing
# 1278 th batch processing
# 1279 th batch processing
# 1280 th batch processing
# 1281 th batch processing
# 1282 th batch processing
# 1283 th batch processing
# 1284 th batch processing
# 1285 th batch processing
# 1286 th batch processing
# 1287 th batch processing
# 1288 th batch processing
# 1289 th batch processing
# 1290 th batch processing
# 1291 th batch processing
# 1292 th batch processing
# 1293 th batch processing
# 1294 th batch processing
# 1295 th batch processing
# 1296 th batch processing
# 1297 th batch processing
# 1298 th batch processing
# 1299 th batch processing
# 1300 th batch processing
# 1301 th batch processing
# 1302 th batch processing
# 1303 th batch processing
# 1304 th batch processing
# 1305 th batch processing
# 1306 th batch processing
# 1307 th batch processing
# 1308 th batch processing
# 1309 th batch processing
# 1310 th batch processing
# 1311 th batch processing
# 1312 th batch processing
# 1313 th batch processing
# 1314 th batch processing
# 1315 th batch processing
# 1316 th batch processing
# 1317 th batch processing
# 1318 th batch processing
# 1319 th batch processing
# 1320 th batch processing
# 1321 th batch processing
# 1322 th batch processing
# 1323 th batch processing
# 1324 th batch processing
# 1325 th batch processing
# 1326 th batch processing
# 1327 th batch processing
# 1328 th batch processing
# 1329 th batch processing
# 1330 th batch processing
# 1331 th batch processing
# 1332 th batch processing
# 1333 th batch processing
# 1334 th batch processing
# 1335 th batch processing
# 1336 th batch processing
# 1337 th batch processing
# 1338 th batch processing
# 1339 th batch processing
# 1340 th batch processing
# 1341 th batch processing
# 1342 th batch processing
# 1343 th batch processing
# 1344 th batch processing
# 1345 th batch processing
# 1346 th batch processing
# 1347 th batch processing
# 1348 th batch processing
# 1349 th batch processing
# 1350 th batch processing
# 1351 th batch processing
# 1352 th batch processing
# 1353 th batch processing
# 1354 th batch processing
# 1355 th batch processing
# 1356 th batch processing
# 1357 th batch processing
# 1358 th batch processing
# 1359 th batch processing
# 1360 th batch processing
# 1361 th batch processing
# 1362 th batch processing
# 1363 th batch processing
# 1364 th batch processing
# 1365 th batch processing
# 1366 th batch processing
# 1367 th batch processing
# 1368 th batch processing
# 1369 th batch processing
# 1370 th batch processing
# 1371 th batch processing
# 1372 th batch processing
# 1373 th batch processing
# 1374 th batch processing
# 1375 th batch processing
# 1376 th batch processing
# 1377 th batch processing
# 1378 th batch processing
# 1379 th batch processing
# 1380 th batch processing
# 1381 th batch processing
# 1382 th batch processing
# 1383 th batch processing
# 1384 th batch processing
# 1385 th batch processing
# 1386 th batch processing
# 1387 th batch processing
# 1388 th batch processing
# 1389 th batch processing
# 1390 th batch processing
# 1391 th batch processing
# 1392 th batch processing
# 1393 th batch processing
# 1394 th batch processing
# 1395 th batch processing
# 1396 th batch processing
# 1397 th batch processing
# 1398 th batch processing
# 1399 th batch processing
# 1400 th batch processing
# 1401 th batch processing
# 1402 th batch processing
# 1403 th batch processing
